# %% [markdown]
# # Entrega 1
# Optimización 2021-1
#
# Grupo 17

# %% [markdown]
# Importación de librerías necesarias:

# %%
import json
import pandas as pd

# %% [markdown]
# ## 1. Descarga de datos

# %% [markdown]
# Los datos fueron obtenidos por medio de [esta query](https://services3.arcgis.com/YLNLlpguFsVmgseb/arcgis/rest/services/Dosis_por_comuna_puntos/FeatureServer/0/query?f=json&where=1=1&returnGeometry=false&spatialRel=esriSpatialRelIntersects&outFields=*&orderByFields=ORD_REG%20asc&resultOffset=0&resultRecordCount=32000&resultType=standard&cacheHint=true) a los servidores del Ministerio de Bienes Nacionales.

# %%
# !wget https://www.dropbox.com/s/lg8grwkyurfxrpl/vacunas.json
# Out:
# --2021-04-17 21:45:51--  https://www.dropbox.com/s/lg8grwkyurfxrpl/vacunas.json
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.1.18, 2620:100:601a:18::a27d:712
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.1.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/lg8grwkyurfxrpl/vacunas.json [following]
# --2021-04-17 21:45:51--  https://www.dropbox.com/s/raw/lg8grwkyurfxrpl/vacunas.json
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc8b1d779d18cdbd47006b4910a6.dl.dropboxusercontent.com/cd/0/inline/BM0Jw9XGOXVtXqhUotzCNAHpslWZT_s101sPsBYLcey7nExchXMBPyuNxgcFfG6ndXvkw_aFBLI-obyeZM5cWNBxQFxMKgqGyz6JvhfnRAVoAi_IzenEt-8Inb5smyh3UCVh7nxT92bfXuZ-_3XKdIMZ/file# [following]
# --2021-04-17 21:45:51--  https://uc8b1d779d18cdbd47006b4910a6.dl.dropboxusercontent.com/cd/0/inline/BM0Jw9XGOXVtXqhUotzCNAHpslWZT_s101sPsBYLcey7nExchXMBPyuNxgcFfG6ndXvkw_aFBLI-obyeZM5cWNBxQFxMKgqGyz6JvhfnRAVoAi_IzenEt-8Inb5smyh3UCVh7nxT92bfXuZ-_3XKdIMZ/file
# Resolving uc8b1d779d18cdbd47006b4910a6.dl.dropboxusercontent.com (uc8b1d779d18cdbd47006b4910a6.dl.dropboxusercontent.com)... 162.125.1.15, 2620:100:601a:15::a27d:70f
# Connecting to uc8b1d779d18cdbd47006b4910a6.dl.dropboxusercontent.com (uc8b1d779d18cdbd47006b4910a6.dl.dropboxusercontent.com)|162.125.1.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 117283 (115K) [text/plain]
# Saving to: ‘vacunas.json’
#
# vacunas.json        100%[===================>] 114.53K  --.-KB/s    in 0.04s
#
# 2021-04-17 21:45:52 (2.57 MB/s) - ‘vacunas.json’ saved [117283/117283]

# %% [markdown]
# Carga del json de datos:

# %%
with open('vacunas.json', 'r') as file:
    data = file.read()

vaccines = json.loads(data)

# %%
#print(json.dumps(vaccines, sort_keys=True, indent=4))

# %%
len(vaccines['features'])
# Out:
# 346

# %%
vaccines['features'][0]['attributes']
# Out:
# {'COMUNA': 'Arica',
#  'CUT_COM': '15101',
#  'CUT_COM_EN': 15101,
#  'CUT_PROV': '151',
#  'CUT_REG': '15',
#  'CUT_REG_EN': 15,
#  'DOSIS_1': 78951,
#  'DOSIS_2': 52357,
#  'DOSIS_TOT': 131308,
#  'FID': 321,
#  'F_Reporte': 1616630400000,
#  'ID_DOSIS': 1,
#  'ORD_COM': 1,
#  'ORD_REG': 1,
#  'POB_OBJ': 188465,
#  'POB_TOTAL': 250795,
#  'PROVINCIA': 'Arica',
#  'REGION': 'Arica y Parinacota'}

# %% [markdown]
# ## 2. Preprocesamiento

# %% [markdown]
# Los datos fueron transformados a formato `pd.DataFrame`. Luego, se eliminaron comunas que no serían incorporadas en el modelo.
#
# Finalmente, se agregan columnas de interés relacionadas a los porcentajes de vacunación.

# %%
def pandification(my_json):
    data = []
    for commune in my_json['features']:
        row = commune['attributes']
        data.append(row)
    return pd.DataFrame(data)

# %%
df = pandification(vaccines)

df.head()
# Out:
#    FID CUT_REG CUT_PROV CUT_COM  ...      F_Reporte ORD_REG ORD_COM  CUT_COM_EN
# 0  321      15      151   15101  ...  1616630400000       1       1       15101
# 1  322      15      151   15102  ...  1616630400000       1       2       15102
# 2  323      15      152   15201  ...  1616630400000       1       4       15201
# 3  324      15      152   15202  ...  1616630400000       1       3       15202
# 4    1      01      011   01101  ...  1616630400000       2       9        1101
#
# [5 rows x 18 columns]

# %% [markdown]
# Elimina comunas en zona extrema:

# %%
extreme_zone = ['Isla de Pascua', 'Juan Fernández', 'Antártica', 'Cabo de Hornos', 'Porvenir',
                'Primavera', 'Timaukel', 'Laguna Blanca', 'Punta Arenas',
                'Río Verde', 'San Gregorio', 'Natales', 'Torres del Paine']

def get_index(df, elements):
    index = []
    for e in elements:
        index.append(df[df['COMUNA'] == e].index[0])
    return index

extreme_index = get_index(df, extreme_zone)
df = df.drop(extreme_index, axis=0).reset_index()

# %% [markdown]
# Definición de porcentajes:

# %%
df['P_DOSIS_1'] = df['DOSIS_1'] / df['POB_OBJ']
df['P_DOSIS_2'] = df['DOSIS_2'] / df['POB_OBJ']
df['P_DOSIS']   = df['DOSIS_TOT'] / (2*df['POB_OBJ'])

main_columns = ['REGION', 'COMUNA', 'P_DOSIS_1', 'P_DOSIS_2', 'P_DOSIS']

# %% [markdown]
# ## 3. Análisis de datos

# %% [markdown]
# ### 3.1. En general

# %% [markdown]
# En general, la distribución de la vacunación en general se describe de la siguiente forma:

# %%
df.P_DOSIS.describe()
# Out:
# count    333.000000
# mean       0.434413
# std        0.109190
# min        0.105498
# 25%        0.374616
# 50%        0.419665
# 75%        0.479351
# max        1.024230
# Name: P_DOSIS, dtype: float64

# %%
mean_dosis = df.P_DOSIS.mean()

# Cálculo del error medio
abs(df.P_DOSIS - mean_dosis).mean()
# Out:
# 0.07589593629325789

# %% [markdown]
# #### 3.1.1 Por comuna

# %% [markdown]
# Las comunas con los menores porcentajes de vacunación para la primera dosis son:

# %%
df[main_columns].sort_values('P_DOSIS_1').head()
# Out:
#                  REGION         COMUNA  P_DOSIS_1  P_DOSIS_2   P_DOSIS
# 3    Arica y Parinacota  General Lagos   0.139673   0.071322  0.105498
# 8              Tarapacá       Colchane   0.178713   0.125496  0.152105
# 248              Biobío    Alto Biobío   0.218723   0.132391  0.175557
# 169               Maule          Maule   0.247713   0.145638  0.196676
# 5              Tarapacá  Alto Hospicio   0.264641   0.134700  0.199670

# %% [markdown]
# Las comunas con los menores porcentajes de vacunación para la segunda dosis son:

# %%
df[main_columns].sort_values('P_DOSIS_2').head()
# Out:
#                  REGION         COMUNA  P_DOSIS_1  P_DOSIS_2   P_DOSIS
# 3    Arica y Parinacota  General Lagos   0.139673   0.071322  0.105498
# 8              Tarapacá       Colchane   0.178713   0.125496  0.152105
# 248              Biobío    Alto Biobío   0.218723   0.132391  0.175557
# 5              Tarapacá  Alto Hospicio   0.264641   0.134700  0.199670
# 169               Maule          Maule   0.247713   0.145638  0.196676

# %% [markdown]
# Las comunas con los menores porcentajes de vacunación en general son:

# %%
df[main_columns].sort_values('P_DOSIS').head()
# Out:
#                  REGION         COMUNA  P_DOSIS_1  P_DOSIS_2   P_DOSIS
# 3    Arica y Parinacota  General Lagos   0.139673   0.071322  0.105498
# 8              Tarapacá       Colchane   0.178713   0.125496  0.152105
# 248              Biobío    Alto Biobío   0.218723   0.132391  0.175557
# 169               Maule          Maule   0.247713   0.145638  0.196676
# 5              Tarapacá  Alto Hospicio   0.264641   0.134700  0.199670

# %% [markdown]
# #### 3.1.2 Por región

# %% [markdown]
# Distribución de los datos en cada región, **ordenados por promedio**:

# %%
df.groupby(by=df.REGION).describe()['P_DOSIS'].sort_values('mean')
# Out:
#                                            count      mean  ...       75%       max
# REGION                                                      ...
# Arica y Parinacota                           4.0  0.267205  ...  0.358101  0.387317
# Tarapacá                                     7.0  0.304897  ...  0.384360  0.401623
# Metropolitana de Santiago                   52.0  0.380648  ...  0.395392  0.765867
# Atacama                                      9.0  0.382987  ...  0.386723  0.483904
# Antofagasta                                  9.0  0.399522  ...  0.374521  0.654130
# Coquimbo                                    15.0  0.414622  ...  0.450537  0.504119
# Los Lagos                                   30.0  0.424971  ...  0.457804  0.559768
# Biobío                                      33.0  0.427915  ...  0.478436  0.567233
# La Araucanía                                32.0  0.432565  ...  0.475951  0.545525
# Los Ríos                                    12.0  0.432608  ...  0.450690  0.508818
# Maule                                       30.0  0.450760  ...  0.468156  0.736425
# Libertador General Bernardo O'Higgins       33.0  0.465311  ...  0.496212  0.760847
# Aysén del General Carlos Ibáñez del Campo   10.0  0.466341  ...  0.514913  0.563910
# Valparaíso                                  36.0  0.504575  ...  0.527280  1.024230
# Ñuble                                       21.0  0.513849  ...  0.562744  0.629592
#
# [15 rows x 8 columns]

# %% [markdown]
# Distribución de los datos en cada región, **ordenados por desviación estandar**:

# %%
df.groupby(by=df.REGION).describe()['P_DOSIS'].sort_values('std', ascending=False)
# Out:
#                                            count      mean  ...       75%       max
# REGION                                                      ...
# Valparaíso                                  36.0  0.504575  ...  0.527280  1.024230
# Arica y Parinacota                           4.0  0.267205  ...  0.358101  0.387317
# Antofagasta                                  9.0  0.399522  ...  0.374521  0.654130
# Metropolitana de Santiago                   52.0  0.380648  ...  0.395392  0.765867
# Libertador General Bernardo O'Higgins       33.0  0.465311  ...  0.496212  0.760847
# Tarapacá                                     7.0  0.304897  ...  0.384360  0.401623
# Maule                                       30.0  0.450760  ...  0.468156  0.736425
# Biobío                                      33.0  0.427915  ...  0.478436  0.567233
# Ñuble                                       21.0  0.513849  ...  0.562744  0.629592
# Aysén del General Carlos Ibáñez del Campo   10.0  0.466341  ...  0.514913  0.563910
# La Araucanía                                32.0  0.432565  ...  0.475951  0.545525
# Los Lagos                                   30.0  0.424971  ...  0.457804  0.559768
# Coquimbo                                    15.0  0.414622  ...  0.450537  0.504119
# Atacama                                      9.0  0.382987  ...  0.386723  0.483904
# Los Ríos                                    12.0  0.432608  ...  0.450690  0.508818
#
# [15 rows x 8 columns]

# %% [markdown]
# ### 3.2 Casos particulares

# %% [markdown]
# #### 3.2.1 Arica y Parinacota

# %% [markdown]
# La descripción de esta región es:

# %%
df[df.REGION == 'Arica y Parinacota'].P_DOSIS.describe()
# Out:
# count    4.000000
# mean     0.267205
# std      0.127446
# min      0.105498
# 25%      0.197108
# 50%      0.288003
# 75%      0.358101
# max      0.387317
# Name: P_DOSIS, dtype: float64

# %% [markdown]
# Análisis de las comunas en la región:

# %%
df[df.REGION == 'Arica y Parinacota'][main_columns]
# Out:
#                REGION         COMUNA  P_DOSIS_1  P_DOSIS_2   P_DOSIS
# 0  Arica y Parinacota          Arica   0.418916   0.277808  0.348362
# 1  Arica y Parinacota      Camarones   0.441951   0.332683  0.387317
# 2  Arica y Parinacota          Putre   0.296635   0.158654  0.227644
# 3  Arica y Parinacota  General Lagos   0.139673   0.071322  0.105498

# %% [markdown]
# #### 3.2.2 Metropolitana de Santiago

# %% [markdown]
# La descripción de esta región es:

# %%
df[df.REGION == 'Metropolitana de Santiago'].P_DOSIS.describe()
# Out:
# count    52.000000
# mean      0.380648
# std       0.109491
# min       0.230557
# 25%       0.326644
# 50%       0.363233
# 75%       0.395392
# max       0.765867
# Name: P_DOSIS, dtype: float64

# %% [markdown]
# Análisis de las comunas de la región, **ordenadas por porcentaje de vacunación**:

# %%
df[df.REGION == 'Metropolitana de Santiago'][main_columns].sort_values('P_DOSIS')
# Out:
#                         REGION               COMUNA  ...  P_DOSIS_2   P_DOSIS
# 116  Metropolitana de Santiago                Lampa  ...   0.159721  0.230557
# 85   Metropolitana de Santiago     Estación Central  ...   0.199760  0.255078
# 104  Metropolitana de Santiago            Quilicura  ...   0.174172  0.259702
# 82   Metropolitana de Santiago          Cerro Navia  ...   0.198592  0.268122
# 91   Metropolitana de Santiago           La Pintana  ...   0.210612  0.273333
# 112  Metropolitana de Santiago          Puente Alto  ...   0.212121  0.274294
# 118  Metropolitana de Santiago         San Bernardo  ...   0.205426  0.277940
# 107  Metropolitana de Santiago                Renca  ...   0.200947  0.279491
# 115  Metropolitana de Santiago               Colina  ...   0.199664  0.284989
# 101  Metropolitana de Santiago            Peñalolén  ...   0.242296  0.316395
# 128  Metropolitana de Santiago             El Monte  ...   0.237006  0.317576
# 98   Metropolitana de Santiago                Maipú  ...   0.241182  0.318516
# 106  Metropolitana de Santiago             Recoleta  ...   0.253952  0.324748
# 80   Metropolitana de Santiago             Santiago  ...   0.244740  0.327276
# 84   Metropolitana de Santiago            El Bosque  ...   0.251635  0.328811
# 95   Metropolitana de Santiago            Lo Espejo  ...   0.246007  0.332560
# 105  Metropolitana de Santiago        Quinta Normal  ...   0.260984  0.332578
# 103  Metropolitana de Santiago             Pudahuel  ...   0.227335  0.337018
# 131  Metropolitana de Santiago             Peñaflor  ...   0.256623  0.337586
# 87   Metropolitana de Santiago        Independencia  ...   0.270292  0.338763
# 81   Metropolitana de Santiago            Cerrillos  ...   0.253303  0.342908
# 100  Metropolitana de Santiago  Pedro Aguirre Cerda  ...   0.275921  0.351286
# 119  Metropolitana de Santiago                 Buin  ...   0.251278  0.353350
# 117  Metropolitana de Santiago               Tiltil  ...   0.267759  0.356809
# 126  Metropolitana de Santiago            San Pedro  ...   0.278303  0.363050
# 121  Metropolitana de Santiago                Paine  ...   0.270454  0.363113
# 88   Metropolitana de Santiago          La Cisterna  ...   0.281279  0.363353
# 127  Metropolitana de Santiago            Talagante  ...   0.278290  0.368754
# 110  Metropolitana de Santiago            San Ramón  ...   0.290239  0.369973
# 130  Metropolitana de Santiago        Padre Hurtado  ...   0.255942  0.371573
# 97   Metropolitana de Santiago                Macul  ...   0.293068  0.380882
# 122  Metropolitana de Santiago            Melipilla  ...   0.291793  0.381952
# 108  Metropolitana de Santiago          San Joaquín  ...   0.287400  0.382523
# 83   Metropolitana de Santiago             Conchalí  ...   0.291924  0.386453
# 109  Metropolitana de Santiago           San Miguel  ...   0.299953  0.387228
# 99   Metropolitana de Santiago                Ñuñoa  ...   0.295204  0.387494
# 96   Metropolitana de Santiago             Lo Prado  ...   0.294560  0.390018
# 129  Metropolitana de Santiago        Isla de Maipo  ...   0.300363  0.392678
# 125  Metropolitana de Santiago          María Pinto  ...   0.306506  0.392719
# 124  Metropolitana de Santiago             Curacaví  ...   0.307321  0.403413
# 123  Metropolitana de Santiago                Alhué  ...   0.309881  0.412010
# 90   Metropolitana de Santiago            La Granja  ...   0.315311  0.413980
# 86   Metropolitana de Santiago           Huechuraba  ...   0.287719  0.414924
# 89   Metropolitana de Santiago           La Florida  ...   0.338516  0.418979
# 113  Metropolitana de Santiago               Pirque  ...   0.340527  0.435490
# 114  Metropolitana de Santiago    San José de Maipo  ...   0.347960  0.470884
# 120  Metropolitana de Santiago      Calera de Tango  ...   0.359481  0.473656
# 93   Metropolitana de Santiago           Las Condes  ...   0.377914  0.501903
# 94   Metropolitana de Santiago         Lo Barnechea  ...   0.384324  0.511277
# 92   Metropolitana de Santiago             La Reina  ...   0.553347  0.716326
# 111  Metropolitana de Santiago             Vitacura  ...   0.602593  0.753529
# 102  Metropolitana de Santiago          Providencia  ...   0.607937  0.765867
#
# [52 rows x 5 columns]
